# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# __Задание 1:__ Поиск переменных из случайного шума

# %%
df = pd.read_csv(r'C:\Users\jsb24\РАБОТА\Полезное для работы\1T_Data_eng\Task_5_1\dataset_0.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   feature_0   1014 non-null   float64
#  1   feature_1   1014 non-null   float64
#  2   feature_2   1014 non-null   float64
#  3   feature_3   1014 non-null   int64
#  4   feature_4   1014 non-null   float64
#  5   feature_5   1014 non-null   float64
#  6   feature_6   1014 non-null   float64
#  7   feature_7   1014 non-null   float64
#  8   feature_8   1014 non-null   float64
#  9   feature_9   1014 non-null   float64
#  10  feature_10  1014 non-null   float64
#  11  feature_11  1014 non-null   float64
#  12  feature_12  1014 non-null   float64
#  13  feature_13  1014 non-null   float64
#  14  feature_14  1014 non-null   float64
#  15  feature_15  1014 non-null   float64
#  16  feature_16  1014 non-null   float64
#  17  feature_17  1014 non-null   float64
# ...

# %%
df.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -2.899907   0.416956  -2.537387          1   0.525815  -2.830056
# 1  -0.503141   0.283345   0.325574          1   0.317668   0.599717
# 2  -6.560124  -1.334441   0.562320          0   0.087322  -4.781831
# 3 -10.912819   0.308334  -3.496197          0   0.082024 -12.598419
# 4  -4.609628  -2.721853   1.713445          0   0.370517   6.739384
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_12  feature_13  \
# 0  -2.770089  -0.522188  -0.016822   3.997906  ...   -2.772272    0.335127
# 1  -0.270953   1.359805   1.725321   2.288644  ...   -0.838587    0.888538
# 2  -0.238253  -0.821628  -2.615665   2.330243  ...   -1.525412   -0.696060
# 3  -0.247768  -1.128131  -5.131549   2.679787  ...   -4.801637    1.103051
# 4  -1.282858   3.624201   3.042493   4.732795  ...   -2.447469    1.322181
#
#    feature_14  feature_15  feature_16  feature_17  feature_18  feature_19  \
# ...

# %%
df.describe()
# Out:
#          feature_0    feature_1    feature_2    feature_3    feature_4  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean     -2.992791     0.354827    -2.724893     0.503945     0.989091
# std       4.586396     1.242543     5.773157     0.500231     0.995562
# min     -18.683715    -3.681904   -43.557242     0.000000     0.000605
# 25%      -5.375026    -0.390112    -3.001561     0.000000     0.303611
# 50%      -0.712725     0.228473    -0.660930     1.000000     0.646654
# 75%       0.294861     0.966569     0.264393     1.000000     1.339636
# max       3.571550     5.228342     5.802537     1.000000     8.114341
#
#          feature_5    feature_6    feature_7    feature_8    feature_9  ...  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000  ...
# mean     -3.229856    -1.229476    -1.590139    -1.081217     2.205249  ...
# std       5.915039     2.292950     4.132736     2.389788     3.155064  ...
# ...

# %% [markdown]
# __Необходимо найти и идентифицировать переменные, которые являются случайным шумом и не имеют значимой корреляции или влияния на другие переменные в датасете.__

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)  # посмотрим тепловую карту - видим, что не влияет особо feature_9,18,19
# Out:
# <Axes: >

# %%
print(df.corr())
# Out:
#             feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# feature_0    1.000000  -0.445882   0.718022   0.017232  -0.028595   0.876545
# feature_1   -0.445882   1.000000  -0.348553   0.012270   0.017090  -0.590349
# feature_2    0.718022  -0.348553   1.000000   0.031645  -0.021594   0.767453
# feature_3    0.017232   0.012270   0.031645   1.000000   0.074552   0.013563
# feature_4   -0.028595   0.017090  -0.021594   0.074552   1.000000  -0.023609
# feature_5    0.876545  -0.590349   0.767453   0.013563  -0.023609   1.000000
# feature_6    0.770567  -0.329847   0.766485  -0.000218  -0.013039   0.769511
# feature_7    0.610861  -0.395517   0.848043   0.045997  -0.013679   0.737816
# feature_8    0.799336  -0.558050   0.762273   0.006293  -0.021414   0.937778
# feature_9   -0.840904   0.314252  -0.714552  -0.030137   0.022988  -0.717879
# feature_10   0.761964  -0.314873   0.892111   0.054474  -0.018203   0.733972
# ...

# %% [markdown]
# __Ответ__: по моему мнению, feature_9,18,19 особо ни на что не влияют, именно они являются шумом.

# %% [markdown]
# __Задание 2__: Анализ зависимостей с использованием pandas и библиотек для построения графиков
#
# Используйте dataset_1.csv
#
# Опишите зависимость между переменными и таргетом без использования моделей, только с помощью pandas и библиотек для визуализации данных.

# %%
data = pd.read_csv(r'C:\Users\jsb24\РАБОТА\Полезное для работы\1T_Data_eng\Task_5_1\dataset_1.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  1000 non-null   float64
#  1   feature_2  1000 non-null   float64
#  2   target     1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
data.head()
# Out:
#    feature_1  feature_2  target
# 0  -0.532193   0.814028       0
# 1  -0.212750   1.011712       0
# 2   0.306720   0.959148       0
# 3   0.786851  -0.031955       1
# 4  -0.239004  -0.757634       1

# %%
data.describe()
# Out:
#          feature_1    feature_2      target
# count  1000.000000  1000.000000  1000.00000
# mean      0.001016     0.000118     0.50000
# std       0.641268     0.640570     0.50025
# min      -1.042947    -1.055231     0.00000
# 25%      -0.621492    -0.621425     0.00000
# 50%       0.005128    -0.001786     0.50000
# 75%       0.617814     0.619077     1.00000
# max       1.048049     1.070260     1.00000

# %%
print(data.corr()) #  мы видим, что коэффициент корреляции около нуля, это означает, что линейной взаимосвязи между features нет
# Out:
#            feature_1  feature_2    target
# feature_1   1.000000  -0.001197 -0.001485
# feature_2  -0.001197   1.000000 -0.001763
# target     -0.001485  -0.001763  1.000000

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)             # связь между ними нелинейная и сложная, ниже увидим на графиках.

# %% [markdown]
# __Ответ:__ Видим, что коэффициент корреляции около нуля, это означает, что линейной взаимосвязи между features нет, связь между ними сложная.
